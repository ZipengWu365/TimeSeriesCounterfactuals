# %% [markdown]
# # Heatwave and ER visits demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo heatwave-health"
command
# Out:
# 'python -m tscfbench demo heatwave-health'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2024-07-14 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 46,
  "avg_effect": 7.133922974639801,
  "avg_abs_effect": 8.107136970924474,
  "cum_effect": 328.1604568334308,
  "max_abs_effect": 24.581714895602005,
  "command": "python -m tscfbench demo heatwave-health",
  "image": "../docs/assets/demo_heatwave_health_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2024-07-14 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 46,
#   "avg_effect": 7.133922974639801,
#   "avg_abs_effect": 8.107136970924474,
#   "cum_effect": 328.1604568334308,
#   "max_abs_effect": 24.581714895602005,
#   "command": "python -m tscfbench demo heatwave-health",
#   "image": "../docs/assets/demo_heatwave_health_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_heatwave_health_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
