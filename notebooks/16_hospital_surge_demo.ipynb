# %% [markdown]
# # Hospital surge during a respiratory outbreak demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo hospital-surge"
command
# Out:
# 'python -m tscfbench demo hospital-surge'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2024-01-17 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 33,
  "avg_effect": 12.496994547344444,
  "avg_abs_effect": 12.496994547344444,
  "cum_effect": 412.4008200623667,
  "max_abs_effect": 18.515436538065543,
  "command": "python -m tscfbench demo hospital-surge",
  "image": "../docs/assets/demo_hospital_surge_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2024-01-17 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 33,
#   "avg_effect": 12.496994547344444,
#   "avg_abs_effect": 12.496994547344444,
#   "cum_effect": 412.4008200623667,
#   "max_abs_effect": 18.515436538065543,
#   "command": "python -m tscfbench demo hospital-surge",
#   "image": "../docs/assets/demo_hospital_surge_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_hospital_surge_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
