# %% [markdown]
# # Repo breakout after a launch demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo repo-breakout"
command
# Out:
# 'python -m tscfbench demo repo-breakout'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2025-12-18 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 32,
  "avg_effect": 22.0343672111358,
  "avg_abs_effect": 22.0343672111358,
  "cum_effect": 705.0997507563457,
  "max_abs_effect": 36.71357696179269,
  "command": "python -m tscfbench demo repo-breakout",
  "image": "../docs/assets/demo_repo_breakout_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2025-12-18 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 32,
#   "avg_effect": 22.0343672111358,
#   "avg_abs_effect": 22.0343672111358,
#   "cum_effect": 705.0997507563457,
#   "max_abs_effect": 36.71357696179269,
#   "command": "python -m tscfbench demo repo-breakout",
#   "image": "../docs/assets/demo_repo_breakout_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_repo_breakout_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
