# %% [markdown]
# # Electricity demand after a grid shock demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo electricity-shock"
command
# Out:
# 'python -m tscfbench demo electricity-shock'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "treated_unit": "North Grid",
  "intervention_t": "2024-03-13 00:00:00",
  "model": "simple_scm",
  "post_pre_rmspe_ratio": 1.6654586172175085,
  "cum_effect": -1321.942802942362,
  "avg_effect": -34.78796849848321,
  "space_placebo_pvalue": 0.2,
  "time_placebo_pvalue": 0.2222222222222222,
  "command": "python -m tscfbench demo electricity-shock",
  "image": "../docs/assets/demo_electricity_shock_share_card.png"
}
summary
# Out:
# {
#   "treated_unit": "North Grid",
#   "intervention_t": "2024-03-13 00:00:00",
#   "model": "simple_scm",
#   "post_pre_rmspe_ratio": 1.6654586172175085,
#   "cum_effect": -1321.942802942362,
#   "avg_effect": -34.78796849848321,
#   "space_placebo_pvalue": 0.2,
#   "time_placebo_pvalue": 0.2222222222222222,
#   "command": "python -m tscfbench demo electricity-shock",
#   "image": "../docs/assets/demo_electricity_shock_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_electricity_shock_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
