# %% [markdown]
# # Detector downtime after a solar storm demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo detector-downtime"
command
# Out:
# 'python -m tscfbench demo detector-downtime'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2024-05-18 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 38,
  "avg_effect": -3.326632863846303,
  "avg_abs_effect": 3.326632863846303,
  "cum_effect": -126.4120488261595,
  "max_abs_effect": 3.917955897668463,
  "command": "python -m tscfbench demo detector-downtime",
  "image": "../docs/assets/demo_detector_downtime_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2024-05-18 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 38,
#   "avg_effect": -3.326632863846303,
#   "avg_abs_effect": 3.326632863846303,
#   "cum_effect": -126.4120488261595,
#   "max_abs_effect": 3.917955897668463,
#   "command": "python -m tscfbench demo detector-downtime",
#   "image": "../docs/assets/demo_detector_downtime_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_detector_downtime_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
