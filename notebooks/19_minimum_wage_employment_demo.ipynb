# %% [markdown]
# # Regional employment after a minimum-wage change demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo minimum-wage-employment"
command
# Out:
# 'python -m tscfbench demo minimum-wage-employment'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "treated_unit": "Metro State",
  "intervention_t": "2024-08-04 00:00:00",
  "model": "simple_scm",
  "post_pre_rmspe_ratio": 2.1445679871852312,
  "cum_effect": -196.3555045141637,
  "avg_effect": -3.8501079316502684,
  "space_placebo_pvalue": 0.2,
  "time_placebo_pvalue": 0.2222222222222222,
  "command": "python -m tscfbench demo minimum-wage-employment",
  "image": "../docs/assets/demo_minimum_wage_employment_share_card.png"
}
summary
# Out:
# {
#   "treated_unit": "Metro State",
#   "intervention_t": "2024-08-04 00:00:00",
#   "model": "simple_scm",
#   "post_pre_rmspe_ratio": 2.1445679871852312,
#   "cum_effect": -196.3555045141637,
#   "avg_effect": -3.8501079316502684,
#   "space_placebo_pvalue": 0.2,
#   "time_placebo_pvalue": 0.2222222222222222,
#   "command": "python -m tscfbench demo minimum-wage-employment",
#   "image": "../docs/assets/demo_minimum_wage_employment_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_minimum_wage_employment_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
