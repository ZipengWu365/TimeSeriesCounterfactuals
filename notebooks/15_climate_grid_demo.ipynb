# %% [markdown]
# # Climate shock and grid demand demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo climate-grid"
command
# Out:
# 'python -m tscfbench demo climate-grid'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "treated_unit": "Coastal Grid",
  "intervention_t": "2024-08-11 00:00:00",
  "model": "simple_scm",
  "post_pre_rmspe_ratio": 0.3921238603634598,
  "cum_effect": 77.85374600681807,
  "avg_effect": 2.3592044244490324,
  "space_placebo_pvalue": 1.0,
  "time_placebo_pvalue": 0.8888888888888888,
  "command": "python -m tscfbench demo climate-grid",
  "image": "../docs/assets/demo_climate_grid_share_card.png"
}
summary
# Out:
# {
#   "treated_unit": "Coastal Grid",
#   "intervention_t": "2024-08-11 00:00:00",
#   "model": "simple_scm",
#   "post_pre_rmspe_ratio": 0.3921238603634598,
#   "cum_effect": 77.85374600681807,
#   "avg_effect": 2.3592044244490324,
#   "space_placebo_pvalue": 1.0,
#   "time_placebo_pvalue": 0.8888888888888888,
#   "command": "python -m tscfbench demo climate-grid",
#   "image": "../docs/assets/demo_climate_grid_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_climate_grid_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
