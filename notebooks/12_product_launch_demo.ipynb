# %% [markdown]
# # Product launch signups demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo product-launch"
command
# Out:
# 'python -m tscfbench demo product-launch'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2024-04-23 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 48,
  "avg_effect": 28.333677439879125,
  "avg_abs_effect": 28.333677439879125,
  "cum_effect": 1360.016517114198,
  "max_abs_effect": 36.236615659068065,
  "command": "python -m tscfbench demo product-launch",
  "image": "../docs/assets/demo_product_launch_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2024-04-23 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 48,
#   "avg_effect": 28.333677439879125,
#   "avg_abs_effect": 28.333677439879125,
#   "cum_effect": 1360.016517114198,
#   "max_abs_effect": 36.236615659068065,
#   "command": "python -m tscfbench demo product-launch",
#   "image": "../docs/assets/demo_product_launch_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_product_launch_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
