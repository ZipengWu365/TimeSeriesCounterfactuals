# %% [markdown]
# # Viral attention spike demo
#
# This notebook is a checked-output walkthrough for one tscfbench path.

# %% [markdown]
# ## Why this notebook exists
#
# The goal is to show a concrete workflow outcome, not just a code skeleton.

# %%
command = "python -m tscfbench demo viral-attention"
command
# Out:
# 'python -m tscfbench demo viral-attention'

# %% [markdown]
# ## Summary payload

# %%
summary = {
  "intervention_t": "2025-10-14 00:00:00",
  "model": "ols_impact",
  "controls": 2,
  "post_period_points": 52,
  "avg_effect": 12.583379988669293,
  "avg_abs_effect": 12.583379988669293,
  "cum_effect": 654.3357594108032,
  "max_abs_effect": 25.55841712763531,
  "command": "python -m tscfbench demo viral-attention",
  "image": "../docs/assets/demo_viral_attention_share_card.png"
}
summary
# Out:
# {
#   "intervention_t": "2025-10-14 00:00:00",
#   "model": "ols_impact",
#   "controls": 2,
#   "post_period_points": 52,
#   "avg_effect": 12.583379988669293,
#   "avg_abs_effect": 12.583379988669293,
#   "cum_effect": 654.3357594108032,
#   "max_abs_effect": 25.55841712763531,
#   "command": "python -m tscfbench demo viral-attention",
#   "image": "../docs/assets/demo_viral_attention_share_card.png"
# }

# %% [markdown]
# ## What to look for
#
# Focus on whether the observed line departs from the counterfactual after the event and whether the summary can be explained in one sentence.

# %% [markdown]
# ![preview](../docs/assets/demo_viral_attention_share_card.png)

# %%
next_step = 'python -m tscfbench make-share-package --demo-id repo-breakout'
next_step
# Out:
# 'python -m tscfbench make-share-package --demo-id repo-breakout'
